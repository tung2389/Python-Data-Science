# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(5, 5, 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plotting example')
plt.show()

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot(5, 5, 'o')
# Out:
# <img src="data:image/png;base64,..." width="160">
